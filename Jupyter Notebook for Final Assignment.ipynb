# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Jorge Benitez</b><br>
# Data & Program Specialist

# %% [markdown]
# *I am interested in Data Science because I like to identify patterns in the data you are working on, then make data-driven decisions to achive goals or objectives*

# %% [markdown]
# ### The next code will be a multiplication between two variables (a and b) defined by me previous the operation

# %%
a=1
b=4
a*b
# Out:
# 4

# %% [markdown]
# ---
# **What I learned in this course**
# - Data Scientist's Toolkit
#     1. Languages for Data Science
#     2. Data Science Tools
#     3. Packages, APIs, Data sets and Models
# - Open Source Tools
#     1. Jupyter Notebook and JupyterLab
#     2. RStudio IDE
#     3. GitHub
# - IBM Tools for Data Science
#     1. Watson Studio
#     2. Other IBM Tools
#
# Thank you [IBM], I learned a lot!
#
# [IBM]: https://www.ibm.com/us-en?ar=1
